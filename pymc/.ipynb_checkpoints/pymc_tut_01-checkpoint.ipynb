# %%
import pymc
import numpy as np
# %matplotlib inline

import t1_pymc

S = pymc.MCMC(t1_pymc, db='pickle')
S.sample(iter=10000, burn=5000, thin=2)
pymc.Matplot.plot(S)
# Out:
#  [-----------------100%-----------------] 10000 of 10000 complete in 0.9 secPlotting theta_0
# Plotting theta_1
# Plotting theta_2
# Plotting theta_3
# Plotting beta
# Plotting alpha

# %%
import DisasterModel

print DisasterModel.s.parents
print DisasterModel.D.parents
print DisasterModel.r.children
print DisasterModel.r.parents
# Out:
# {'upper': 110, 'lower': 0}
# {'mu': <pymc.PyMCObjects.Deterministic 'r' at 0x7f1c7c90c490>}
# set([<pymc.distributions.Poisson 'D' at 0x7f1c7c90c4d0>])
# {'s': <pymc.distributions.DiscreteUniform 's' at 0x7f1c7c90ca10>, 'e': <pymc.distributions.Exponential 'e' at 0x7f1c7c90c410>, 'l': <pymc.distributions.Exponential 'l' at 0x7f1c7c90c310>}

# %%
M = pymc.MCMC(DisasterModel)
M.sample(iter=10000, burn=1000, thin=10)
pymc.Matplot.plot(M)
# Out:
#  [-----------------100%-----------------] 10000 of 10000 complete in 1.5 secPlotting s
# Plotting e
# Plotting l

# %%
from pylab import hist, show
hist(M.trace("s")[:], bins=20)
show()

# %%
import DisasterModel2 as dm2
reload(dm2)

M2 = pymc.MCMC(dm2)
M2.sample(iter=10000, burn=1000, thin=10)
pymc.Matplot.plot(M2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-32e740b37937> in <module>()
# ----> 1 import DisasterModel2 as dm2
#       2
#       3 M2 = pymc.MCMC(dm2)
#       4 M2.sample(iter=10000, burn=1000, thin=10)
#       5 pymc.Matplot.plot(M2)
#
# /home2/yannick2/github/Spikes/pymc/DisasterModel2.py in <module>()
#      24     return out
#      25
# ---> 26 D = Impute("D", Poisson, mu=r, value=disasters_array)
#
# TypeError: Impute() takes exactly 3 arguments (2 given)
