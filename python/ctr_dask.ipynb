# %%
from dask.distributed import Client, progress
client = Client(processes=False, threads_per_worker=4,
                n_workers=1, memory_limit='12GB')
client
# Out:
# <Client: scheduler='inproc://192.168.1.12/12192/1' processes=1 cores=4>

# %%
import dask.array as da
import dask.dataframe as dd
from dask import compute

import os

# %%
dirname = "/home/yannick/tmp"

filename = os.path.join(dirname, "train.gz")

# %%
#df = dd.read_csv(filename, compression="gzip")

dirname = "/home4/yannick4/tmp"

df = dd.read_parquet(dirname + "/train_dask.parquet/", index=False)

df
# Out:
# Dask DataFrame Structure:
#                     id  click   hour     C1 banner_pos site_id site_domain site_category  app_id app_domain app_category device_id device_ip device_model device_type device_conn_type    C14    C15    C16    C17    C18    C19    C20    C21
# npartitions=99
#                 object  int64  int64  int64      int64  object      object        object  object     object       object    object    object       object       int64            int64  int64  int64  int64  int64  int64  int64  int64  int64
#                    ...    ...    ...    ...        ...     ...         ...           ...     ...        ...          ...       ...       ...          ...         ...              ...    ...    ...    ...    ...    ...    ...    ...    ...
# ...

# %%
# %time df.head()
# Out:
# CPU times: user 2.69 s, sys: 268 ms, total: 2.96 s
# Wall time: 2 s
#                      id  click      hour    C1  banner_pos   site_id  \
# 0   1000009418151094273      0  14102100  1005           0  1fbe01fe
# 1  10000169349117863715      0  14102100  1005           0  1fbe01fe
# 2  10000371904215119486      0  14102100  1005           0  1fbe01fe
# 3  10000640724480838376      0  14102100  1005           0  1fbe01fe
# 4  10000679056417042096      0  14102100  1005           1  fe8cc448
#
#   site_domain site_category    app_id app_domain ...  device_type  \
# 0    f3845767      28905ebd  ecad2386   7801e8d9 ...            1
# 1    f3845767      28905ebd  ecad2386   7801e8d9 ...            1
# 2    f3845767      28905ebd  ecad2386   7801e8d9 ...            1
# 3    f3845767      28905ebd  ecad2386   7801e8d9 ...            1
# 4    9166c161      0569f928  ecad2386   7801e8d9 ...            1
#
#   device_conn_type    C14  C15  C16   C17  C18  C19     C20  C21
# ...

# %%
# %time compute(df.groupby("click").id.agg("count"))
# Out:
# CPU times: user 3min 8s, sys: 3min 9s, total: 6min 18s
# Wall time: 1min 32s
# (click
#  0    33563901
#  1     6865066
#  Name: id, dtype: int64,)

# %%
# %time df.describe().compute()
# Out:
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 2.85 GB -- Worker memory limit: 4.00 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 3.04 GB -- Worker memory limit: 4.00 GB
# distributed.worker - WARNING - Worker is at 111% memory usage. Pausing worker.  Process memory: 5.17 GB -- Worker memory limit: 4.00 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.15 GB -- Worker memory limit: 4.00 GB
# distributed.worker - WARNING - Worker is at 64% memory usage. Resuming worker. Process memory: 2.57 GB -- Worker memory limit: 4.00 GB
# ...
