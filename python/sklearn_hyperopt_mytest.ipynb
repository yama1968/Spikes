# %%
import sklearn.datasets
import numpy as np
import random
from math import log

data = sklearn.datasets.load_digits()
X = data["data"]
y = data["target"]

from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

old_score = -1000
step = 1

# define an objective function
def objective(args):

    global old_score, step
    
    clf = SVC(**args)
    this_scores = cross_val_score(clf, X, y, scoring="accuracy", cv=3)
    this_score = this_scores.mean()

    if old_score < this_score:
        print("%d / %.4f (%.4f) with %s" % 
              (step, this_score, this_scores.std(), str(args)))
        old_score = this_score
    
    step = step+1
    
    return -this_score
              

# define a search space
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials

space ={
    'C':      hp.loguniform('C', log(1e-9), log(1e9)),
    'gamma':  hp.loguniform('gamma', log(1e-9), log(1e9))
}


trials = Trials()

# %time best = fmin(objective, space, algo=tpe.suggest, max_evals=200, trials=trials)

print (best)
# Out:
# 1 / 0.1561 (0.0771) with {'C': 0.06607402908036146, 'gamma': 1.1127870233447425e-05}
# 4 / 0.9471 (0.0103) with {'C': 67250.21212231215, 'gamma': 2.51481078239467e-08}
# 9 / 0.9521 (0.0127) with {'C': 79.35913420544244, 'gamma': 5.675549665319751e-06}
# 33 / 0.9672 (0.0054) with {'C': 392781.22352083167, 'gamma': 0.0002750146043138622}
# 47 / 0.9711 (0.0034) with {'C': 2533915.7636671984, 'gamma': 0.00035792285244984936}
# 62 / 0.9761 (0.0034) with {'C': 340.72772017069315, 'gamma': 0.0008106219644125533}
# 100%|██████████| 200/200 [02:07<00:00,  2.70it/s, best loss: -0.9760791584915501]
# CPU times: user 2min 7s, sys: 104 ms, total: 2min 7s
# Wall time: 2min 7s
# {'C': 340.72772017069315, 'gamma': 0.0008106219644125533}

# %%
trials.results
# Out:
# [{'loss': -0.9493535210520859, 'status': 'ok'},
#  {'loss': -0.15664794037813373, 'status': 'ok'},
#  {'loss': -0.15552937214547155, 'status': 'ok'},
#  {'loss': -0.905385173445358, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.1633593497741069, 'status': 'ok'},
#  {'loss': -0.15552937214547155, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.1488179627494984, 'status': 'ok'},
#  {'loss': -0.10183809697768631, 'status': 'ok'},
#  {'loss': -0.1342765757248899, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.1633593497741069, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.15552937214547155, 'status': 'ok'},
#  {'loss': -0.9760763574024867, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.1633593497741069, 'status': 'ok'},
#  {'loss': -0.15552937214547155, 'status': 'ok'},
#  {'loss': -0.15552937214547155, 'status': 'ok'},
#  {'loss': -0.11913677309055591, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.9499100319971848, 'status': 'ok'},
#  {'loss': -0.11691081306365403, 'status': 'ok'},
#  {'loss': -0.9465710500800851, 'status': 'ok'},
#  {'loss': -0.14977168549488631, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.9354188970687307, 'status': 'ok'},
#  {'loss': -0.9660650696649772, 'status': 'ok'},
#  {'loss': -0.12700588221258566, 'status': 'ok'},
#  {'loss': -0.9632825986929765, 'status': 'ok'},
#  {'loss': -0.9510257712229523, 'status': 'ok'},
#  {'loss': -0.15552937214547155, 'status': 'ok'},
#  {'loss': -0.16727433858842455, 'status': 'ok'},
#  {'loss': -0.15552937214547155, 'status': 'ok'},
#  {'loss': -0.9554805482014818, 'status': 'ok'},
#  {'loss': -0.9521750397639873, 'status': 'ok'},
#  {'loss': -0.10351594932667961, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.15552937214547155, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.15552937214547155, 'status': 'ok'},
#  {'loss': -0.11078664283898386, 'status': 'ok'},
#  {'loss': -0.15552937214547155, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.9760763574024867, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.9532880337363538, 'status': 'ok'},
#  {'loss': -0.4981468205691086, 'status': 'ok'},
#  {'loss': -0.13483585984122098, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.9744096535740848, 'status': 'ok'},
#  {'loss': -0.9393199362733936, 'status': 'ok'},
#  {'loss': -0.12085375693294358, 'status': 'ok'},
#  {'loss': -0.9465626468128948, 'status': 'ok'},
#  {'loss': -0.9443534374847111, 'status': 'ok'},
#  {'loss': -0.10183809697768631, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.1454622580515118, 'status': 'ok'},
#  {'loss': -0.9538110712018476, 'status': 'ok'},
#  {'loss': -0.15552937214547155, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.9699660809518088, 'status': 'ok'},
#  {'loss': -0.4747884830335212, 'status': 'ok'},
#  {'loss': -0.9705114433763166, 'status': 'ok'},
#  {'loss': -0.9465738511691485, 'status': 'ok'},
#  {'loss': -0.9443534374847111, 'status': 'ok'},
#  {'loss': -0.10686885293560276, 'status': 'ok'},
#  {'loss': -0.973293886430486, 'status': 'ok'},
#  {'loss': -0.1342765757248899, 'status': 'ok'},
#  {'loss': -0.9443534374847111, 'status': 'ok'},
#  {'loss': -0.9543452013522703, 'status': 'ok'},
#  {'loss': -0.8782478999928195, 'status': 'ok'},
#  {'loss': -0.9760763574024867, 'status': 'ok'},
#  {'loss': -0.3451475825273735, 'status': 'ok'},
#  {'loss': -0.10183809697768631, 'status': 'ok'},
#  {'loss': -0.9716383032048442, 'status': 'ok'},
#  {'loss': -0.10407523344301069, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.15552937214547155, 'status': 'ok'},
#  {'loss': -0.15552937214547155, 'status': 'ok'},
#  {'loss': -0.9348623861236317, 'status': 'ok'},
#  {'loss': -0.9420968050672675, 'status': 'ok'},
#  {'loss': -0.10239738109401741, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.958836197063806, 'status': 'ok'},
#  {'loss': -0.12980230279424113, 'status': 'ok'},
#  {'loss': -0.11189123354416013, 'status': 'ok'},
#  {'loss': -0.9537915194140659, 'status': 'ok'},
#  {'loss': -0.8986961169262299, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'},
#  {'loss': -0.15552937214547155, 'status': 'ok'},
#  {'loss': -0.9348623861236317, 'status': 'ok'},
#  {'loss': -0.13483585984122098, 'status': 'ok'},
#  {'loss': -0.16814710892928506, 'status': 'ok'},
#  {'loss': -0.9081759918488866, 'status': 'ok'},
#  {'loss': -0.1012788128613552, 'status': 'ok'}]
