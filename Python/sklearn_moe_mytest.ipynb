# %%
import sklearn.datasets
import numpy as np
import random
import moe

data = sklearn.datasets.load_digits()
X = data["data"]
y = data["target"]

from sklearn.svm import SVC
from sklearn.cross_validation import cross_val_score

from moe.easy_interface.experiment import Experiment
from moe.easy_interface.simple_endpoint import gp_next_points
from moe.optimal_learning.python.data_containers import SamplePoint


def p2p(point):
    return {'C': 10**point[0], 'gamma': 10**point[1], 'kernel': 'rbf'}

def optimize(expe, n = 100):

    best_score = 0
    
    for i in range(n):
        next_point = gp_next_points(expe)[0]

        print p2p(next_point), " -> ",

        clf = SVC(**p2p(next_point))

        this_scores = cross_val_score(clf, X, y, scoring="accuracy")
        this_score = this_scores.mean()

        print("%.4f (%.4f)" % (this_score, this_scores.std()))

        if this_score > best_score:
            best_score = this_score
            best_expe  = expe
            best_point = next_point

        expe.historical_data.append_sample_points(
            [SamplePoint(next_point, -this_score)])

    return best_score, best_point


expe = Experiment([[-9, 9], [-9, 9]])

# %time best_score, best_point = optimize(expe)
        
print ("best is %.4f, with %s" % (best_score, str(p2p(best_point))))
# Out:
# {'kernel': 'rbf', 'C': 474153.1931395911, 'gamma': 0.3042977501186809}  ->  0.1030 (0.0020)
# {'kernel': 'rbf', 'C': 4313453.850137816, 'gamma': 0.004561943388493181}  ->  0.8982 (0.0208)
# {'kernel': 'rbf', 'C': 639254.6464528856, 'gamma': 0.0015797418116759924}  ->  0.9722 (0.0081)
# {'kernel': 'rbf', 'C': 3460386.4887146144, 'gamma': 0.0004725474880044015}  ->  0.9727 (0.0051)
# {'kernel': 'rbf', 'C': 379710.55548638105, 'gamma': 0.00011619229384899169}  ->  0.9566 (0.0060)
# {'kernel': 'rbf', 'C': 2228896.7083574464, 'gamma': 2.0894819206956306e-05}  ->  0.9466 (0.0096)
# {'kernel': 'rbf', 'C': 279977.9831522841, 'gamma': 6.300765315397067e-06}  ->  0.9455 (0.0091)
# {'kernel': 'rbf', 'C': 1766469.0977570913, 'gamma': 1.2053980228710035e-06}  ->  0.9444 (0.0098)
# {'kernel': 'rbf', 'C': 210438.28542730043, 'gamma': 3.2884018203941096e-07}  ->  0.9438 (0.0103)
# {'kernel': 'rbf', 'C': 1301328.8555798484, 'gamma': 6.308879957839691e-08}  ->  0.9444 (0.0098)
# {'kernel': 'rbf', 'C': 156882.46204443264, 'gamma': 1.8012559268651096e-08}  ->  0.9460 (0.0110)
# {'kernel': 'rbf', 'C': 972984.2604966131, 'gamma': 3.418380067540757e-09}  ->  0.9455 (0.0091)
# {'kernel': 'rbf', 'C': 117002.03118117525, 'gamma': 1e-09}  ->  0.9432 (0.0124)
# {'kernel': 'rbf', 'C': 267237.4975836578, 'gamma': 3.93998528071922e-09}  ->  0.9483 (0.0108)
# {'kernel': 'rbf', 'C': 9034.490669861354, 'gamma': 2.309242324703609e-09}  ->  0.9082 (0.0039)
# {'kernel': 'rbf', 'C': 7975.882812894594, 'gamma': 3.9317391782934175e-08}  ->  0.9465 (0.0159)
# {'kernel': 'rbf', 'C': 15860095.224249749, 'gamma': 1.18955631397739e-08}  ->  0.9449 (0.0094)
# {'kernel': 'rbf', 'C': 24224.62048991417, 'gamma': 8.99331222937863e-09}  ->  0.9493 (0.0134)
# {'kernel': 'rbf', 'C': 11751.092075809858, 'gamma': 6.235091976142901e-07}  ->  0.9444 (0.0098)
# {'kernel': 'rbf', 'C': 25573595.82399582, 'gamma': 1.9035082868114355e-07}  ->  0.9444 (0.0098)
# {'kernel': 'rbf', 'C': 28707.35355279153, 'gamma': 1.455622788989628e-07}  ->  0.9460 (0.0110)
# {'kernel': 'rbf', 'C': 748.8236801519206, 'gamma': 3.341968679157567e-07}  ->  0.9471 (0.0142)
# {'kernel': 'rbf', 'C': 331.6792604360732, 'gamma': 2.6141746344198345e-08}  ->  0.8642 (0.0144)
# {'kernel': 'rbf', 'C': 34044314.21255495, 'gamma': 3.3143222070702444e-06}  ->  0.9444 (0.0098)
# {'kernel': 'rbf', 'C': 335959177.8299279, 'gamma': 7.383787044515401e-07}  ->  0.9444 (0.0098)
# {'kernel': 'rbf', 'C': 314113375.4818193, 'gamma': 4.742551665133353e-08}  ->  0.9438 (0.0103)
# {'kernel': 'rbf', 'C': 13609.75914176545, 'gamma': 2.2752264699267782e-05}  ->  0.9466 (0.0096)
# {'kernel': 'rbf', 'C': 1351.0647687118314, 'gamma': 6.32934953439929e-06}  ->  0.9455 (0.0091)
# {'kernel': 'rbf', 'C': 1500.7711795225694, 'gamma': 0.0001163762374426876}  ->  0.9566 (0.0060)
# {'kernel': 'rbf', 'C': 16508.25966423168, 'gamma': 0.00045178143812051687}  ->  0.9733 (0.0049)
# {'kernel': 'rbf', 'C': 1854.2662189494763, 'gamma': 0.001979892280983555}  ->  0.9700 (0.0061)
# {'kernel': 'rbf', 'C': 16072.93304202905, 'gamma': 0.0072689316626990685}  ->  0.7792 (0.0365)
# {'kernel': 'rbf', 'C': 80611390.90708786, 'gamma': 6.263172669970842e-05}  ->  0.9533 (0.0060)
# {'kernel': 'rbf', 'C': 449950882.8984409, 'gamma': 1.2554573640933154e-05}  ->  0.9466 (0.0083)
# {'kernel': 'rbf', 'C': 82681767.42005874, 'gamma': 0.001408554664619376}  ->  0.9739 (0.0074)
# {'kernel': 'rbf', 'C': 717120938.5019048, 'gamma': 0.0002641810667462197}  ->  0.9672 (0.0054)
# {'kernel': 'rbf', 'C': 982043762.7411677, 'gamma': 0.004214409270918242}  ->  0.9160 (0.0157)
# {'kernel': 'rbf', 'C': 112138062.60320845, 'gamma': 0.02258669233233664}  ->  0.2505 (0.0257)
# {'kernel': 'rbf', 'C': 383859164.533788, 'gamma': 0.0009737580540534568}  ->  0.9761 (0.0041)
# {'kernel': 'rbf', 'C': 131.62788405789823, 'gamma': 0.0006914006324787132}  ->  0.9750 (0.0036)
# {'kernel': 'rbf', 'C': 83.91573552391593, 'gamma': 4.849841826443443e-05}  ->  0.9510 (0.0078)
# {'kernel': 'rbf', 'C': 63.00930416538223, 'gamma': 2.1440000099686026e-06}  ->  0.9471 (0.0104)
# {'kernel': 'rbf', 'C': 33.4000629677757, 'gamma': 1.5681341319570279e-07}  ->  0.7295 (0.0067)
# {'kernel': 'rbf', 'C': 202.28285766763426, 'gamma': 0.011813465530696841}  ->  0.6278 (0.0295)
# {'kernel': 'rbf', 'C': 5.756047787088805, 'gamma': 1.0415276002894851e-05}  ->  0.9354 (0.0145)
# {'kernel': 'rbf', 'C': 7.410601698149891, 'gamma': 0.00018084564392831796}  ->  0.9639 (0.0090)
# {'kernel': 'rbf', 'C': 0.6155544563767714, 'gamma': 6.0917803789714387e-05}  ->  0.9243 (0.0077)
# {'kernel': 'rbf', 'C': 0.5957488789116572, 'gamma': 0.0008890679150732989}  ->  0.9711 (0.0078)
# {'kernel': 'rbf', 'C': 5.615241038808423, 'gamma': 0.003197149324264066}  ->  0.9483 (0.0093)
# {'kernel': 'rbf', 'C': 0.5909969233679043, 'gamma': 0.0152006583168483}  ->  0.1180 (0.0122)
# {'kernel': 'rbf', 'C': 2.063236689519866, 'gamma': 0.0005624202805733899}  ->  0.9738 (0.0067)
# {'kernel': 'rbf', 'C': 0.05592589659835799, 'gamma': 0.00024413599191657812}  ->  0.8859 (0.0144)
# {'kernel': 'rbf', 'C': 21.979385737087103, 'gamma': 0.0013658061468133928}  ->  0.9739 (0.0074)
# {'kernel': 'rbf', 'C': 180131556.22503638, 'gamma': 2.1992766090297435e-09}  ->  0.9449 (0.0083)
# {'kernel': 'rbf', 'C': 19344049.993706826, 'gamma': 1e-09}  ->  0.9443 (0.0075)
# {'kernel': 'rbf', 'C': 232.71744116594263, 'gamma': 1.0259615750411141e-09}  ->  0.1555 (0.0763)
# {'kernel': 'rbf', 'C': 0.055705929490638705, 'gamma': 8.162689695379603e-06}  ->  0.1561 (0.0771)
# {'kernel': 'rbf', 'C': 91808979.07907826, 'gamma': 8.468995349566474e-09}  ->  0.9432 (0.0094)
# {'kernel': 'rbf', 'C': 1000000000.0, 'gamma': 7.094481313901958e-09}  ->  0.9444 (0.0087)
# {'kernel': 'rbf', 'C': 0.2903568681157215, 'gamma': 0.0002704008249966004}  ->  0.9471 (0.0138)
# {'kernel': 'rbf', 'C': 0.01168767497343887, 'gamma': 0.00197883618894595}  ->  0.1628 (0.0866)
# {'kernel': 'rbf', 'C': 28001745.680136044, 'gamma': 0.0004600203266260099}  ->  0.9727 (0.0051)
# {'kernel': 'rbf', 'C': 0.001729197971871816, 'gamma': 7.26423560021089e-05}  ->  0.1578 (0.0795)
# {'kernel': 'rbf', 'C': 3596.923202788283, 'gamma': 0.24657436161972}  ->  0.1035 (0.0027)
# {'kernel': 'rbf', 'C': 1.7596347999865667, 'gamma': 6.858165232007479e-09}  ->  0.1555 (0.0763)
# {'kernel': 'rbf', 'C': 1000000000.0, 'gamma': 1e-09}  ->  0.9443 (0.0075)
# {'kernel': 'rbf', 'C': 0.016898416112256617, 'gamma': 1.0284780540180496e-09}  ->  0.1555 (0.0763)
# {'kernel': 'rbf', 'C': 0.0001318723260485786, 'gamma': 2.5969638334470655e-09}  ->  0.1555 (0.0763)
# {'kernel': 'rbf', 'C': 2.3597242781482475e-06, 'gamma': 5.180383932065335e-08}  ->  0.1555 (0.0763)
# {'kernel': 'rbf', 'C': 1.480124870139849e-07, 'gamma': 1.1311562432374049e-09}  ->  0.1555 (0.0763)
# {'kernel': 'rbf', 'C': 1.5869861718458085e-08, 'gamma': 7.769544172989824e-08}  ->  0.1555 (0.0763)
# {'kernel': 'rbf', 'C': 1.1050070174564887e-09, 'gamma': 1.3008706018684718e-09}  ->  0.1555 (0.0763)
# {'kernel': 'rbf', 'C': 3.183472265642288e-07, 'gamma': 4.6220273043568235e-06}  ->  0.1555 (0.0763)
# {'kernel': 'rbf', 'C': 2.5574222505203755e-09, 'gamma': 8.29377559681916e-06}  ->  0.1561 (0.0771)
# {'kernel': 'rbf', 'C': 3.8881154275041615e-08, 'gamma': 0.0005246301874652393}  ->  0.1628 (0.0866)
# {'kernel': 'rbf', 'C': 4.506575558856048e-06, 'gamma': 0.00043814779168412305}  ->  0.1622 (0.0858)
# {'kernel': 'rbf', 'C': 5.178463197105486e-07, 'gamma': 0.03191205559275324}  ->  0.1035 (0.0027)
# {'kernel': 'rbf', 'C': 2.1781967410541525e-09, 'gamma': 0.028017380732724927}  ->  0.1035 (0.0027)
# {'kernel': 'rbf', 'C': 1.7782620144568734e-08, 'gamma': 3.2742313819596474}  ->  0.1153 (0.0193)
# {'kernel': 'rbf', 'C': 3.5168060023399333e-06, 'gamma': 4.335973344202416}  ->  0.1097 (0.0114)
# {'kernel': 'rbf', 'C': 1.7503154816619594e-07, 'gamma': 291.98134768489916}  ->  0.1013 (0.0005)
# {'kernel': 'rbf', 'C': 3.654042742105413e-05, 'gamma': 735.7254945027529}  ->  0.1013 (0.0005)
# {'kernel': 'rbf', 'C': 1.0577678246372708e-09, 'gamma': 311.58051010798306}  ->  0.1013 (0.0005)
# {'kernel': 'rbf', 'C': 0.0008691117470398251, 'gamma': 8.925447564676134}  ->  0.1018 (0.0004)
# {'kernel': 'rbf', 'C': 0.007981389350181715, 'gamma': 1132.1486335955503}  ->  0.1013 (0.0005)
# {'kernel': 'rbf', 'C': 0.0003660425330168892, 'gamma': 75539.10496903188}  ->  0.1013 (0.0005)
# {'kernel': 'rbf', 'C': 1.5163487045400073e-06, 'gamma': 47792.1236083651}  ->  0.1013 (0.0005)
# {'kernel': 'rbf', 'C': 1.0157883147744736e-08, 'gamma': 42575.53909381085}  ->  0.1013 (0.0005)
# {'kernel': 'rbf', 'C': 6.45029745773811e-08, 'gamma': 5810456.351522918}  ->  0.1013 (0.0005)
# {'kernel': 'rbf', 'C': 1.2771400447150197e-05, 'gamma': 5454079.469676357}  ->  0.1013 (0.0005)
# {'kernel': 'rbf', 'C': 1.1373308533369551e-06, 'gamma': 595965209.4058744}  ->  0.1013 (0.0005)
# {'kernel': 'rbf', 'C': 0.0003010267857056373, 'gamma': 505114192.00057936}  ->  0.1013 (0.0005)
# {'kernel': 'rbf', 'C': 0.006027602573773013, 'gamma': 7471866.790543247}  ->  0.1013 (0.0005)
# {'kernel': 'rbf', 'C': 0.10876764202335579, 'gamma': 102698.06380252147}  ->  0.1013 (0.0005)
# {'kernel': 'rbf', 'C': 1.853956445491899, 'gamma': 835.2227186372828}  ->  0.1013 (0.0005)
# {'kernel': 'rbf', 'C': 0.059543094805405206, 'gamma': 990748114.2079936}  ->  0.1013 (0.0005)
# {'kernel': 'rbf', 'C': 1.3877007802989743, 'gamma': 10649528.502860848}  ->  0.1013 (0.0005)
# {'kernel': 'rbf', 'C': 24.55710501715945, 'gamma': 88588.54488899604}  ->  0.1013 (0.0005)
# {'kernel': 'rbf', 'C': 449.89232719374513, 'gamma': 721.6464616882688}  ->  0.1013 (0.0005)
# {'kernel': 'rbf', 'C': 6172.43129368665, 'gamma': 61686.00502198723}  ->  0.1013 (0.0005)
# CPU times: user 53.1 s, sys: 73.7 ms, total: 53.2 s
# Wall time: 3min 8s
# best is 0.9761, with {'kernel': 'rbf', 'C': 383859164.533788, 'gamma': 0.0009737580540534568}
