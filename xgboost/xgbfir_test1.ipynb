# %%
from sklearn.datasets import load_iris, load_boston
import xgboost as xgb
import xgbfir

# loading database
boston = load_boston()

# doing all the XGBoost magic
xgb_rmodel = xgb.XGBRegressor().fit(boston['data'], boston['target'])

# saving to file with proper feature names
xgbfir.saveXgbFI(xgb_rmodel, feature_names=boston.feature_names, OutputXlsxFile = 'bostonFI.xlsx')


# loading database
iris = load_iris()

# doing all the XGBoost magic
xgb_cmodel = xgb.XGBClassifier().fit(iris['data'], iris['target'])

# saving to file with proper feature names
xgbfir.saveXgbFI(xgb_cmodel, feature_names=iris.feature_names, OutputXlsxFile = 'irisFI.xlsx')

# %%
# !ls
# Out:
# bostonFI.xlsx  xgbfir_test1.ipynb    xgboost_reverse_eng.R
# irisFI.xlsx    xgboost.dumped.trees

# %%
import pandas as pd

irisFI = [pd.read_excel("irisFI.xlsx", sheetname = "Interaction Depth %d" % i) for i in range(3)]

irisFI[0]
# Out:
#          Interaction         Gain  FScore     wFScore  Average wFScore  \
# 0  petal length (cm)  1118.079372     187  132.558313         0.708868
# 1   petal width (cm)   464.870057      91   53.470347         0.587586
# 2   sepal width (cm)     7.286136      13    3.379455         0.259958
# 3  sepal length (cm)     0.874860       4    1.509316         0.377329
#
#    Average Gain  Expected Gain  Gain Rank  FScore Rank  wFScore Rank  \
# 0      5.979034    1073.079117          1            1             1
# 1      5.108462     360.367071          2            2             2
# 2      0.560472       1.699613          3            3             3
# 3      0.218715       0.305381          4            4             4
#
#    Avg wFScore Rank  Avg Gain Rank  Expected Gain Rank  Average Rank  \
# 0                 1              1                   1      1.000000
# 1                 2              2                   2      2.000000
# 2                 4              3                   3      3.166667
# 3                 3              4                   4      3.833333
#
#    Average Tree Index  Average Tree Depth
# 0           46.032086            0.860963
# 1           46.010989            1.120879
# 2           74.615385            2.000000
# 3           46.000000            2.000000

# %%
irisFI[1]
# Out:
#                            Interaction         Gain  FScore    wFScore  \
# 0   petal length (cm)|petal width (cm)  1920.118079     153  72.934703
# 1  petal length (cm)|petal length (cm)    31.356615      15  11.834454
# 2   petal length (cm)|sepal width (cm)     9.348975      12   3.083513
# 3    petal width (cm)|petal width (cm)     9.329158      10   1.259504
# 4   petal width (cm)|sepal length (cm)     9.040308       4   1.509316
# 5    petal width (cm)|sepal width (cm)     2.641939       1   0.295941
#
#    Average wFScore  Average Gain  Expected Gain  Gain Rank  FScore Rank  \
# 0         0.476697     12.549791     978.922533          1            1
# 1         0.788964      2.090441      24.726203          2            2
# 2         0.256959      0.779081       2.515083          3            3
# 3         0.125950      0.932916       1.142205          4            4
# 4         0.377329      2.260077       2.670050          5            5
# 5         0.295941      2.641939       0.781859          6            6
#
#    wFScore Rank  Avg wFScore Rank  Avg Gain Rank  Expected Gain Rank  \
# 0             1                 2              1                   1
# 1             2                 1              4                   2
# 2             3                 5              6                   4
# 3             5                 6              5                   5
# 4             4                 3              3                   3
# 5             6                 4              2                   6
#
#    Average Rank  Average Tree Index  Average Tree Depth
# 0      1.166667           39.294118            1.490196
# 1      2.166667           85.066667            1.000000
# 2      4.000000           75.500000            2.000000
# 3      4.833333           55.700000            2.000000
# 4      3.833333           46.000000            2.000000
# 5      5.000000           64.000000            2.000000

# %%
irisFI[2]
# Out:
#                                          Interaction         Gain  FScore  \
# 0  petal length (cm)|petal length (cm)|petal widt...  1464.857236      75
# 1  petal length (cm)|petal width (cm)|petal width...    78.989698      10
# 2  petal length (cm)|petal width (cm)|sepal width...    39.922409       9
# 3  petal length (cm)|petal width (cm)|sepal lengt...    35.990478       4
# 4  petal length (cm)|petal length (cm)|sepal widt...     8.684945       4
#
#      wFScore  Average wFScore  Average Gain  Expected Gain  Gain Rank  \
# 0  28.415800         0.378877     19.531430     468.366545          1
# 1   1.259504         0.125950      7.898970       8.557152          2
# 2   1.514336         0.168260      4.435823       6.555003          3
# 3   1.509316         0.377329      8.997620      13.318473          4
# 4   1.865118         0.466280      2.171236       4.035946          5
#
#    FScore Rank  wFScore Rank  Avg wFScore Rank  Avg Gain Rank  \
# 0            1             1                 2              1
# 1            2             5                 5              3
# 2            3             3                 4              4
# 3            4             4                 3              2
# 4            5             2                 1              5
#
#    Expected Gain Rank  Average Rank  Average Tree Index  Average Tree Depth
# 0                   1      1.166667           36.693333                   2
# 1                   3      3.333333           55.700000                   2
# 2                   4      3.500000           66.222222                   2
# 3                   2      3.166667           46.000000                   2
# 4                   5      3.833333           93.500000                   2
